# %%
from server import *
import warnings
warnings.filterwarnings("ignore")

# %%
args = Args(training_rounds=800,local_epochs=5,rule_arg=0.3,batch_size=50,learning_rate=0.1,rho=0.01,lambd=0.1,aggr_scheme="FedAvg",model_type="ResNet",random_selection=10,n_clients=100)
serve = FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.030, 0.390, 0.000, 0.040, 0.004, 0.164, 0.000, 0.124, 0.226, 0.022, Amount:500
# Client   1: 0.108, 0.040, 0.222, 0.080, 0.026, 0.014, 0.126, 0.302, 0.058, 0.024, Amount:500
# Client   2: 0.032, 0.406, 0.000, 0.030, 0.040, 0.016, 0.050, 0.266, 0.018, 0.142, Amount:500
# Client   3: 0.106, 0.270, 0.000, 0.000, 0.076, 0.002, 0.000, 0.056, 0.428, 0.062, Amount:500
# Client   4: 0.070, 0.034, 0.082, 0.070, 0.002, 0.444, 0.284, 0.002, 0.012, 0.000, Amount:500
# Client   5: 0.238, 0.026, 0.006, 0.002, 0.004, 0.080, 0.538, 0.000, 0.000, 0.106, Amount:500
# Client   6: 0.052, 0.026, 0.026, 0.052, 0.020, 0.132, 0.016, 0.554, 0.078, 0.044, Amount:500
# Client   7: 0.034, 0.020, 0.414, 0.094, 0.126, 0.102, 0.184, 0.018, 0.004, 0.004, Amount:500
# Client   8: 0.050, 0.112, 0.004, 0.002, 0.070, 0.026, 0.046, 0.614, 0.036, 0.040, Amount:500
# Client   9: 0.022, 0.206, 0.028, 0.630, 0.032, 0.042, 0.008, 0.008, 0.018, 0.006, Amount:500
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1000
# F1 Score: 0.0182
# Training Round Complete!
# Training: Round 2 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1179
# F1 Score: 0.0457
# Training Round Complete!
# Training: Round 3 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1151
# F1 Score: 0.0393
# Training Round Complete!
# Training: Round 4 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1007
# F1 Score: 0.0199
# Training Round Complete!
# Training: Round 5 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1333
# F1 Score: 0.0743
# Training Round Complete!
# Training: Round 6 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1000
# F1 Score: 0.0182
# Training Round Complete!
# Training: Round 7 / 800
# ...

# %%
args = Args(training_rounds=800,local_epochs=5,rule_arg=0.3,batch_size=50,learning_rate=0.1,rho=0.01,lambd=0.1,aggr_scheme="FedSAM",model_type="ResNet",random_selection=10,n_clients=100)
serve = FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.030, 0.390, 0.000, 0.040, 0.004, 0.164, 0.000, 0.124, 0.226, 0.022, Amount:500
# Client   1: 0.108, 0.040, 0.222, 0.080, 0.026, 0.014, 0.126, 0.302, 0.058, 0.024, Amount:500
# Client   2: 0.032, 0.406, 0.000, 0.030, 0.040, 0.016, 0.050, 0.266, 0.018, 0.142, Amount:500
# Client   3: 0.106, 0.270, 0.000, 0.000, 0.076, 0.002, 0.000, 0.056, 0.428, 0.062, Amount:500
# Client   4: 0.070, 0.034, 0.082, 0.070, 0.002, 0.444, 0.284, 0.002, 0.012, 0.000, Amount:500
# Client   5: 0.238, 0.026, 0.006, 0.002, 0.004, 0.080, 0.538, 0.000, 0.000, 0.106, Amount:500
# Client   6: 0.052, 0.026, 0.026, 0.052, 0.020, 0.132, 0.016, 0.554, 0.078, 0.044, Amount:500
# Client   7: 0.034, 0.020, 0.414, 0.094, 0.126, 0.102, 0.184, 0.018, 0.004, 0.004, Amount:500
# Client   8: 0.050, 0.112, 0.004, 0.002, 0.070, 0.026, 0.046, 0.614, 0.036, 0.040, Amount:500
# Client   9: 0.022, 0.206, 0.028, 0.630, 0.032, 0.042, 0.008, 0.008, 0.018, 0.006, Amount:500
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.0994
# F1 Score: 0.0217
# Training Round Complete!
# Training: Round 2 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1290
# F1 Score: 0.0718
# Training Round Complete!
# Training: Round 3 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1357
# F1 Score: 0.0725
# Training Round Complete!
# Training: Round 4 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1528
# F1 Score: 0.0746
# Training Round Complete!
# Training: Round 5 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1098
# F1 Score: 0.0384
# Training Round Complete!
# Training: Round 6 / 800
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1506
# F1 Score: 0.0711
# Training Round Complete!
# Training: Round 7 / 800
# ...

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Hessian") # this is with 2 iterations for the Hessian
# and re-definition of perturbation as a simple addition of the eigenvector perturbation to the model to the existing gradient perturbation
serve = FedSAM_Hessian(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1000
# F1 Score: 0.0182
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1564
# F1 Score: 0.0623
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2236
# F1 Score: 0.1590
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2778
# F1 Score: 0.2249
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3141
# F1 Score: 0.2760
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3462
# F1 Score: 0.3040
# Training Round Complete!
# Training: Round 7 / 35
# ...

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Hessian") # this is with 5 iterations for the Hessian
serve = FedSAM_Hessian(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1257
# F1 Score: 0.0598
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1970
# F1 Score: 0.1248
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2554
# F1 Score: 0.1968
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2811
# F1 Score: 0.2327
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3077
# F1 Score: 0.2672
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3480
# F1 Score: 0.3116
# Training Round Complete!
# Training: Round 7 / 35
# ...

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Hessian") # this is with 1 iteration for the Hessian
serve = FedSAM_Hessian(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1003
# F1 Score: 0.0190
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1781
# F1 Score: 0.0882
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2103
# F1 Score: 0.1385
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2574
# F1 Score: 0.2009
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3176
# F1 Score: 0.2745
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3509
# F1 Score: 0.3089
# Training Round Complete!
# Training: Round 7 / 35
# ...

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM") # random peturbation (for demonstration)
# mimics some adverserial perturbation instead of the maximally worst case perturbation
serve = FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1374
# F1 Score: 0.0737
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1959
# F1 Score: 0.1184
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2610
# F1 Score: 0.2023
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2919
# F1 Score: 0.2418
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3051
# F1 Score: 0.2589
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3329
# F1 Score: 0.2922
# Training Round Complete!
# Training: Round 7 / 35
# ...

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedAvg") 
serve = FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1620
# F1 Score: 0.0697
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1965
# F1 Score: 0.1217
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2702
# F1 Score: 0.2202
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2982
# F1 Score: 0.2500
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3151
# F1 Score: 0.2737
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3479
# F1 Score: 0.3118
# Training Round Complete!
# Training: Round 7 / 35
# ...

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM",mu=0.1) 
serve = FedSAM_Trace(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# ...

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1111
# F1 Score: 0.0388
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1640
# F1 Score: 0.0791
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2294
# F1 Score: 0.1751
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2557
# F1 Score: 0.2055
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3167
# F1 Score: 0.2749
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3469
# F1 Score: 0.3060
# Training Round Complete!
# Training: Round 7 / 35
# ...

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Trace") 
serve = FedSAM_Trace(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# ...

# %%
import time
start_time = time.time()
serve.run_experiment()
print("Total Time Taken: ", time.time()-start_time)
print('Average Time per Round: ', (time.time()-start_time)/args.tr_rounds)
print('Experiment Completed')
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1343
# F1 Score: 0.0559
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1765
# F1 Score: 0.0945
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2305
# F1 Score: 0.1719
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2822
# F1 Score: 0.2422
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3198
# F1 Score: 0.2796
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3397
# F1 Score: 0.3032
# Training Round Complete!
# Training: Round 7 / 35
# ...
