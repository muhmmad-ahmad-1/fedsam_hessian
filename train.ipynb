# %%
from server import *
import warnings
warnings.filterwarnings("ignore")

# %%
args = Args(training_rounds=800,local_epochs=5,rule_arg=0.3,batch_size=50,learning_rate=0.001,rho=0.01,lambd=0.1,aggr_scheme="FedAvg",model_type="ResNet",random_selection=2,n_clients=100,random_selection=10)
serve = FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.030, 0.390, 0.000, 0.040, 0.004, 0.164, 0.000, 0.124, 0.226, 0.022, Amount:500
# Client   1: 0.108, 0.040, 0.222, 0.080, 0.026, 0.014, 0.126, 0.302, 0.058, 0.024, Amount:500
# Client   2: 0.032, 0.406, 0.000, 0.030, 0.040, 0.016, 0.050, 0.266, 0.018, 0.142, Amount:500
# Client   3: 0.106, 0.270, 0.000, 0.000, 0.076, 0.002, 0.000, 0.056, 0.428, 0.062, Amount:500
# Client   4: 0.070, 0.034, 0.082, 0.070, 0.002, 0.444, 0.284, 0.002, 0.012, 0.000, Amount:500
# Client   5: 0.238, 0.026, 0.006, 0.002, 0.004, 0.080, 0.538, 0.000, 0.000, 0.106, Amount:500
# Client   6: 0.052, 0.026, 0.026, 0.052, 0.020, 0.132, 0.016, 0.554, 0.078, 0.044, Amount:500
# Client   7: 0.034, 0.020, 0.414, 0.094, 0.126, 0.102, 0.184, 0.018, 0.004, 0.004, Amount:500
# Client   8: 0.050, 0.112, 0.004, 0.002, 0.070, 0.026, 0.046, 0.614, 0.036, 0.040, Amount:500
# Client   9: 0.022, 0.206, 0.028, 0.630, 0.032, 0.042, 0.008, 0.008, 0.018, 0.006, Amount:500
# Client  10: 0.076, 0.024, 0.352, 0.282, 0.004, 0.184, 0.012, 0.000, 0.012, 0.054, Amount:500
# Client  11: 0.050, 0.178, 0.022, 0.056, 0.016, 0.050, 0.010, 0.026, 0.400, 0.192, Amount:500
# Client  12: 0.052, 0.032, 0.034, 0.102, 0.106, 0.022, 0.300, 0.092, 0.016, 0.244, Amount:500
# Client  13: 0.166, 0.026, 0.120, 0.016, 0.006, 0.076, 0.058, 0.254, 0.174, 0.104, Amount:500
# Client  14: 0.618, 0.090, 0.000, 0.102, 0.000, 0.020, 0.000, 0.056, 0.006, 0.108, Amount:500
# Client  15: 0.178, 0.402, 0.008, 0.002, 0.036, 0.002, 0.078, 0.132, 0.140, 0.022, Amount:500
# Client  16: 0.230, 0.282, 0.238, 0.042, 0.002, 0.104, 0.080, 0.000, 0.000, 0.022, Amount:500
# Client  17: 0.282, 0.134, 0.000, 0.066, 0.170, 0.020, 0.150, 0.150, 0.012, 0.016, Amount:500
# Client  18: 0.012, 0.148, 0.068, 0.078, 0.000, 0.174, 0.046, 0.000, 0.032, 0.442, Amount:500
# Client  19: 0.012, 0.190, 0.012, 0.592, 0.030, 0.102, 0.024, 0.000, 0.000, 0.038, Amount:500
# Client  20: 0.002, 0.002, 0.002, 0.000, 0.828, 0.060, 0.086, 0.014, 0.004, 0.002, Amount:500
# Client  21: 0.020, 0.012, 0.002, 0.046, 0.208, 0.012, 0.430, 0.064, 0.008, 0.198, Amount:500
# Client  22: 0.192, 0.192, 0.060, 0.324, 0.004, 0.000, 0.028, 0.050, 0.120, 0.030, Amount:500
# Client  23: 0.292, 0.054, 0.234, 0.034, 0.016, 0.056, 0.082, 0.194, 0.020, 0.018, Amount:500
# Client  24: 0.268, 0.054, 0.000, 0.130, 0.100, 0.160, 0.146, 0.118, 0.006, 0.018, Amount:500
# Client  25: 0.030, 0.004, 0.000, 0.002, 0.538, 0.234, 0.192, 0.000, 0.000, 0.000, Amount:500
# Client  26: 0.132, 0.008, 0.040, 0.046, 0.028, 0.214, 0.000, 0.358, 0.138, 0.036, Amount:500
# Client  27: 0.042, 0.076, 0.072, 0.112, 0.264, 0.012, 0.032, 0.128, 0.230, 0.032, Amount:500
# Client  28: 0.590, 0.052, 0.000, 0.006, 0.000, 0.016, 0.016, 0.116, 0.064, 0.140, Amount:500
# Client  29: 0.034, 0.070, 0.090, 0.092, 0.026, 0.030, 0.026, 0.052, 0.542, 0.038, Amount:500
# Client  30: 0.072, 0.104, 0.010, 0.002, 0.586, 0.162, 0.060, 0.004, 0.000, 0.000, Amount:500
# Client  31: 0.606, 0.110, 0.048, 0.000, 0.004, 0.044, 0.002, 0.150, 0.020, 0.016, Amount:500
# Client  32: 0.460, 0.032, 0.002, 0.018, 0.330, 0.038, 0.000, 0.024, 0.092, 0.004, Amount:500
# Client  33: 0.034, 0.024, 0.000, 0.130, 0.004, 0.272, 0.000, 0.132, 0.368, 0.036, Amount:500
# Client  34: 0.076, 0.164, 0.012, 0.062, 0.002, 0.012, 0.066, 0.014, 0.100, 0.492, Amount:500
# Client  35: 0.188, 0.060, 0.020, 0.218, 0.010, 0.044, 0.172, 0.014, 0.010, 0.264, Amount:500
# Client  36: 0.046, 0.134, 0.000, 0.096, 0.000, 0.002, 0.650, 0.004, 0.018, 0.050, Amount:500
# Client  37: 0.016, 0.544, 0.026, 0.008, 0.028, 0.078, 0.076, 0.084, 0.110, 0.030, Amount:500
# Client  38: 0.016, 0.080, 0.078, 0.266, 0.020, 0.010, 0.004, 0.108, 0.032, 0.386, Amount:500
# Client  39: 0.000, 0.010, 0.000, 0.704, 0.196, 0.000, 0.070, 0.000, 0.012, 0.008, Amount:500
# Client  40: 0.070, 0.164, 0.006, 0.000, 0.088, 0.022, 0.000, 0.000, 0.552, 0.098, Amount:500
# Client  41: 0.324, 0.066, 0.120, 0.034, 0.006, 0.030, 0.258, 0.106, 0.020, 0.036, Amount:500
# Client  42: 0.000, 0.138, 0.024, 0.134, 0.578, 0.026, 0.090, 0.000, 0.000, 0.010, Amount:500
# Client  43: 0.026, 0.234, 0.010, 0.006, 0.042, 0.082, 0.024, 0.352, 0.158, 0.066, Amount:500
# Client  44: 0.144, 0.004, 0.078, 0.438, 0.072, 0.012, 0.072, 0.008, 0.160, 0.012, Amount:500
# Client  45: 0.020, 0.014, 0.114, 0.028, 0.294, 0.028, 0.000, 0.442, 0.038, 0.022, Amount:500
# Client  46: 0.024, 0.014, 0.000, 0.010, 0.206, 0.230, 0.194, 0.000, 0.126, 0.196, Amount:500
# Client  47: 0.072, 0.034, 0.000, 0.022, 0.004, 0.034, 0.088, 0.000, 0.654, 0.092, Amount:500
# Client  48: 0.128, 0.050, 0.160, 0.018, 0.040, 0.134, 0.110, 0.050, 0.256, 0.054, Amount:500
# Client  49: 0.470, 0.286, 0.122, 0.042, 0.022, 0.030, 0.006, 0.002, 0.004, 0.016, Amount:500
# Client  50: 0.038, 0.072, 0.014, 0.338, 0.036, 0.360, 0.038, 0.034, 0.062, 0.008, Amount:500
# Client  51: 0.002, 0.004, 0.002, 0.208, 0.146, 0.514, 0.078, 0.000, 0.010, 0.036, Amount:500
# Client  52: 0.014, 0.192, 0.122, 0.032, 0.064, 0.186, 0.126, 0.054, 0.044, 0.166, Amount:500
# Client  53: 0.016, 0.076, 0.076, 0.012, 0.054, 0.378, 0.094, 0.016, 0.004, 0.274, Amount:500
# Client  54: 0.326, 0.050, 0.086, 0.006, 0.010, 0.004, 0.000, 0.042, 0.026, 0.450, Amount:500
# Client  55: 0.072, 0.070, 0.136, 0.016, 0.002, 0.024, 0.028, 0.420, 0.180, 0.052, Amount:500
# Client  56: 0.012, 0.054, 0.358, 0.132, 0.030, 0.152, 0.000, 0.198, 0.052, 0.012, Amount:500
# Client  57: 0.166, 0.146, 0.190, 0.028, 0.276, 0.006, 0.000, 0.000, 0.002, 0.186, Amount:500
# Client  58: 0.018, 0.044, 0.032, 0.178, 0.440, 0.000, 0.000, 0.246, 0.008, 0.034, Amount:500
# Client  59: 0.168, 0.084, 0.336, 0.062, 0.016, 0.018, 0.062, 0.040, 0.046, 0.168, Amount:500
# Client  60: 0.018, 0.012, 0.298, 0.258, 0.048, 0.208, 0.054, 0.090, 0.002, 0.012, Amount:500
# Client  61: 0.012, 0.020, 0.184, 0.052, 0.396, 0.080, 0.040, 0.000, 0.080, 0.136, Amount:500
# Client  62: 0.040, 0.044, 0.218, 0.034, 0.008, 0.026, 0.130, 0.182, 0.288, 0.030, Amount:500
# Client  63: 0.026, 0.036, 0.000, 0.270, 0.196, 0.044, 0.080, 0.194, 0.006, 0.148, Amount:500
# Client  64: 0.016, 0.042, 0.528, 0.088, 0.066, 0.034, 0.018, 0.004, 0.000, 0.204, Amount:500
# Client  65: 0.126, 0.092, 0.116, 0.052, 0.008, 0.034, 0.016, 0.010, 0.294, 0.252, Amount:500
# Client  66: 0.058, 0.080, 0.004, 0.004, 0.002, 0.022, 0.130, 0.614, 0.050, 0.036, Amount:500
# Client  67: 0.236, 0.028, 0.014, 0.000, 0.490, 0.028, 0.038, 0.000, 0.026, 0.140, Amount:500
# Client  68: 0.030, 0.022, 0.010, 0.394, 0.034, 0.026, 0.036, 0.378, 0.036, 0.034, Amount:500
# Client  69: 0.024, 0.036, 0.164, 0.028, 0.034, 0.170, 0.436, 0.000, 0.050, 0.058, Amount:500
# Client  70: 0.014, 0.010, 0.004, 0.038, 0.454, 0.214, 0.106, 0.004, 0.000, 0.156, Amount:500
# Client  71: 0.304, 0.046, 0.000, 0.040, 0.008, 0.002, 0.506, 0.036, 0.002, 0.056, Amount:500
# Client  72: 0.144, 0.076, 0.000, 0.036, 0.004, 0.068, 0.424, 0.006, 0.192, 0.050, Amount:500
# Client  73: 0.024, 0.182, 0.174, 0.064, 0.028, 0.066, 0.022, 0.162, 0.246, 0.032, Amount:500
# Client  74: 0.064, 0.218, 0.046, 0.062, 0.006, 0.024, 0.000, 0.064, 0.006, 0.510, Amount:500
# Client  75: 0.108, 0.114, 0.406, 0.060, 0.044, 0.196, 0.056, 0.000, 0.000, 0.016, Amount:500
# Client  76: 0.072, 0.066, 0.000, 0.138, 0.006, 0.038, 0.060, 0.014, 0.226, 0.380, Amount:500
# Client  77: 0.000, 0.106, 0.032, 0.098, 0.394, 0.166, 0.204, 0.000, 0.000, 0.000, Amount:500
# Client  78: 0.040, 0.026, 0.014, 0.048, 0.012, 0.158, 0.410, 0.264, 0.002, 0.026, Amount:500
# Client  79: 0.018, 0.018, 0.126, 0.062, 0.008, 0.162, 0.086, 0.300, 0.172, 0.048, Amount:500
# Client  80: 0.018, 0.088, 0.016, 0.440, 0.114, 0.066, 0.008, 0.018, 0.220, 0.012, Amount:500
# Client  81: 0.034, 0.264, 0.042, 0.018, 0.028, 0.000, 0.104, 0.292, 0.170, 0.048, Amount:500
# Client  82: 0.130, 0.240, 0.184, 0.020, 0.016, 0.022, 0.328, 0.012, 0.024, 0.024, Amount:500
# Client  83: 0.114, 0.046, 0.130, 0.116, 0.034, 0.020, 0.132, 0.002, 0.022, 0.384, Amount:500
# Client  84: 0.006, 0.018, 0.582, 0.088, 0.034, 0.044, 0.028, 0.000, 0.000, 0.200, Amount:500
# Client  85: 0.042, 0.010, 0.180, 0.346, 0.210, 0.036, 0.002, 0.144, 0.014, 0.016, Amount:500
# Client  86: 0.014, 0.068, 0.012, 0.122, 0.226, 0.246, 0.272, 0.002, 0.004, 0.034, Amount:500
# Client  87: 0.016, 0.364, 0.084, 0.010, 0.114, 0.204, 0.058, 0.066, 0.070, 0.014, Amount:500
# Client  88: 0.034, 0.084, 0.042, 0.010, 0.004, 0.604, 0.072, 0.030, 0.002, 0.118, Amount:500
# Client  89: 0.020, 0.026, 0.280, 0.078, 0.072, 0.054, 0.076, 0.018, 0.124, 0.252, Amount:500
# Client  90: 0.180, 0.072, 0.062, 0.012, 0.000, 0.022, 0.028, 0.404, 0.018, 0.202, Amount:500
# Client  91: 0.116, 0.034, 0.002, 0.040, 0.236, 0.016, 0.088, 0.004, 0.004, 0.460, Amount:500
# Client  92: 0.046, 0.062, 0.026, 0.012, 0.008, 0.272, 0.092, 0.058, 0.388, 0.036, Amount:500
# Client  93: 0.000, 0.016, 0.636, 0.070, 0.094, 0.160, 0.000, 0.000, 0.022, 0.002, Amount:500
# Client  94: 0.052, 0.000, 0.046, 0.024, 0.060, 0.002, 0.064, 0.032, 0.636, 0.084, Amount:500
# Client  95: 0.062, 0.052, 0.204, 0.040, 0.008, 0.188, 0.082, 0.046, 0.104, 0.214, Amount:500
# Client  96: 0.014, 0.032, 0.324, 0.080, 0.036, 0.028, 0.090, 0.000, 0.360, 0.036, Amount:500
# Client  97: 0.020, 0.018, 0.000, 0.008, 0.054, 0.652, 0.008, 0.212, 0.018, 0.010, Amount:500
# Client  98: 0.038, 0.612, 0.022, 0.002, 0.000, 0.024, 0.052, 0.046, 0.154, 0.050, Amount:500
# Client  99: 0.026, 0.002, 0.470, 0.260, 0.018, 0.072, 0.148, 0.000, 0.002, 0.002, Amount:500
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 20
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.0717
# F1 Score: 0.0413
# Training Round Complete!
# Training: Round 2 / 20
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.0747
# F1 Score: 0.0419
# Training Round Complete!
# Training: Round 3 / 20
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.0784
# F1 Score: 0.0414
# Training Round Complete!
# Training: Round 4 / 20
# Local Training Completed
# Global Aggregation Completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 serve.run_experiment()
#
# File f:\Muhammad Ahmad\fedsam_hessian\server\server.py:168, in Server.run_experiment(self)
#     164 self.update_params()
#     166 print("Model Parameters Initialized")
# --> 168 self.train_and_eval()
#     169 self.metrics['args'] = self.args
#     171 def make_serializable(obj):
#
# File f:\Muhammad Ahmad\fedsam_hessian\server\server.py:330, in Server.train_and_eval(self)
#     327 self.update_params()
#     329 #Record performance on test data (F1 and Accuracy)
# --> 330 self.test_metrics(r)
#     331 print("Training Round Complete!")
#
# File f:\Muhammad Ahmad\fedsam_hessian\server\server.py:293, in Server.test_metrics(self, round)
#     292 def test_metrics(self,round):
# --> 293     acc,f1, trace, top_eigenvalue =  self.test.test(round)
#     295     self.metrics[round]["Accuracy"] = acc
#     296     self.metrics[round]["F1 Score"] = f1
#
# File f:\Muhammad Ahmad\fedsam_hessian\utils\utils_eval.py:44, in Test.test(self, r)
#      42 if r % (self.n_rounds // self.n_traces) == 0 or r == self.n_rounds - 1:
#      43     hessian_comp = hessian(self.model,torch.nn.CrossEntropyLoss(), dataloader=self.dataloader, cuda=True)
# ---> 44     trace  = np.mean(hessian_comp.trace())
#      45     hessian_comp = hessian(self.model,torch.nn.CrossEntropyLoss(), dataloader=self.dataloader, cuda=True)
#      46     top_eigenvalues, _ = hessian_comp.eigenvalues()
#
# File f:\Muhammad Ahmad\fedsam_hessian\pyhessian\hessian.py:183, in hessian.trace(self, maxIter, tol)
#     180     v_i[v_i == 0] = -1
#     182 if self.full_dataset:
# --> 183     _, Hv = self.dataloader_hv_product(v)
#     184 else:
#     185     Hv = hessian_vector_product(self.gradsH, self.params, v)
#
# File f:\Muhammad Ahmad\fedsam_hessian\pyhessian\hessian.py:89, in hessian.dataloader_hv_product(self, v)
#      85 num_data = 0  # count the number of datum points in the dataloader
#      87 THv = [torch.zeros(p.size()).to(device) for p in self.params
#      88       ]  # accumulate result
# ---> 89 for inputs, targets in self.data:
#      90     self.model.zero_grad()
#      91     tmp_num_data = inputs.size(0)
#
# File c:\Users\PCF\.conda\envs\SProj\Lib\site-packages\torch\utils\data\dataloader.py:626, in _BaseDataLoaderIter.__next__(self)
#     625 def __next__(self) -> Any:
# --> 626     with torch.autograd.profiler.record_function(self._profile_name):
#     627         if self._sampler_iter is None:
#     628             # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629             self._reset()  # type: ignore[call-arg]
#
# File c:\Users\PCF\.conda\envs\SProj\Lib\site-packages\torch\autograd\profiler.py:693, in record_function.__exit__(self, exc_type, exc_value, traceback)
#     688     self.record = torch.ops.profiler._record_function_enter_new(
#     689         self.name, self.args
#     690     )
#     691     return self
# --> 693 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any):
#     694     if not self.run_callbacks_on_exit:
#     695         return
#
# KeyboardInterrupt:

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM")
serve = FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1000
# F1 Score: 0.0182
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1757
# F1 Score: 0.1010
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2224
# F1 Score: 0.1583
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2722
# F1 Score: 0.2218
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3096
# F1 Score: 0.2683
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3356
# F1 Score: 0.3003
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3574
# F1 Score: 0.3222
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3796
# F1 Score: 0.3489
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3933
# F1 Score: 0.3649
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4043
# F1 Score: 0.3729
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4144
# F1 Score: 0.3875
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4226
# F1 Score: 0.3944
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4387
# F1 Score: 0.4128
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4414
# F1 Score: 0.4142
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4472
# F1 Score: 0.4226
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4590
# F1 Score: 0.4336
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4588
# F1 Score: 0.4337
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4695
# F1 Score: 0.4426
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4751
# F1 Score: 0.4480
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4817
# F1 Score: 0.4583
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4866
# F1 Score: 0.4606
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4899
# F1 Score: 0.4621
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4995
# F1 Score: 0.4777
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5015
# F1 Score: 0.4760
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5025
# F1 Score: 0.4775
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5147
# F1 Score: 0.4906
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5135
# F1 Score: 0.4879
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5233
# F1 Score: 0.5000
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5301
# F1 Score: 0.5074
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5372
# F1 Score: 0.5153
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5390
# F1 Score: 0.5138
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5377
# F1 Score: 0.5152
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5519
# F1 Score: 0.5321
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5528
# F1 Score: 0.5298
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5591
# F1 Score: 0.5384
# Training Round Complete!

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Hessian") # this is with 2 iterations for the Hessian
# and re-definition of perturbation as a simple addition of the eigenvector perturbation to the model to the existing gradient perturbation
serve = FedSAM_Hessian(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1000
# F1 Score: 0.0182
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1564
# F1 Score: 0.0623
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2236
# F1 Score: 0.1590
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2778
# F1 Score: 0.2249
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3141
# F1 Score: 0.2760
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3462
# F1 Score: 0.3040
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3738
# F1 Score: 0.3390
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3867
# F1 Score: 0.3468
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3945
# F1 Score: 0.3581
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4159
# F1 Score: 0.3749
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4324
# F1 Score: 0.3986
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4317
# F1 Score: 0.3969
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4412
# F1 Score: 0.4117
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4542
# F1 Score: 0.4201
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4444
# F1 Score: 0.4136
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4742
# F1 Score: 0.4432
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4708
# F1 Score: 0.4380
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4772
# F1 Score: 0.4395
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4841
# F1 Score: 0.4500
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4924
# F1 Score: 0.4586
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5012
# F1 Score: 0.4626
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4964
# F1 Score: 0.4632
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4990
# F1 Score: 0.4647
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5103
# F1 Score: 0.4784
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5225
# F1 Score: 0.4833
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5334
# F1 Score: 0.5018
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5396
# F1 Score: 0.5078
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5362
# F1 Score: 0.5090
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5367
# F1 Score: 0.5043
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5545
# F1 Score: 0.5293
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5460
# F1 Score: 0.5188
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5605
# F1 Score: 0.5382
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5706
# F1 Score: 0.5478
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5833
# F1 Score: 0.5652
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5789
# F1 Score: 0.5571
# Training Round Complete!

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Hessian") # this is with 5 iterations for the Hessian
serve = FedSAM_Hessian(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1257
# F1 Score: 0.0598
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1970
# F1 Score: 0.1248
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2554
# F1 Score: 0.1968
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2811
# F1 Score: 0.2327
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3077
# F1 Score: 0.2672
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3480
# F1 Score: 0.3116
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3734
# F1 Score: 0.3390
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3966
# F1 Score: 0.3574
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4039
# F1 Score: 0.3603
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4022
# F1 Score: 0.3721
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4146
# F1 Score: 0.3810
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4139
# F1 Score: 0.3794
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4405
# F1 Score: 0.3999
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4383
# F1 Score: 0.3999
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4605
# F1 Score: 0.4192
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4585
# F1 Score: 0.4191
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4623
# F1 Score: 0.4303
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4725
# F1 Score: 0.4382
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4855
# F1 Score: 0.4428
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4984
# F1 Score: 0.4689
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5079
# F1 Score: 0.4750
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5000
# F1 Score: 0.4652
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5158
# F1 Score: 0.4838
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5152
# F1 Score: 0.4778
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5210
# F1 Score: 0.4879
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5301
# F1 Score: 0.4942
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5337
# F1 Score: 0.4964
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5485
# F1 Score: 0.5175
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5466
# F1 Score: 0.5125
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5609
# F1 Score: 0.5320
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5702
# F1 Score: 0.5465
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5659
# F1 Score: 0.5445
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5721
# F1 Score: 0.5490
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5737
# F1 Score: 0.5515
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5924
# F1 Score: 0.5738
# Training Round Complete!

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Hessian") # this is with 1 iteration for the Hessian
serve = FedSAM_Hessian(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1003
# F1 Score: 0.0190
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1781
# F1 Score: 0.0882
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2103
# F1 Score: 0.1385
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2574
# F1 Score: 0.2009
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3176
# F1 Score: 0.2745
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3509
# F1 Score: 0.3089
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3590
# F1 Score: 0.3210
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3771
# F1 Score: 0.3399
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4047
# F1 Score: 0.3674
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4087
# F1 Score: 0.3678
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4228
# F1 Score: 0.3850
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4263
# F1 Score: 0.3822
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4399
# F1 Score: 0.3994
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4433
# F1 Score: 0.3976
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4537
# F1 Score: 0.4137
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4551
# F1 Score: 0.4219
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4691
# F1 Score: 0.4343
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4669
# F1 Score: 0.4279
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4778
# F1 Score: 0.4351
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4787
# F1 Score: 0.4424
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4937
# F1 Score: 0.4566
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5106
# F1 Score: 0.4773
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5015
# F1 Score: 0.4736
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5048
# F1 Score: 0.4731
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5202
# F1 Score: 0.4902
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5368
# F1 Score: 0.5058
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5280
# F1 Score: 0.4981
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5496
# F1 Score: 0.5259
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5457
# F1 Score: 0.5198
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5358
# F1 Score: 0.5079
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5493
# F1 Score: 0.5189
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5643
# F1 Score: 0.5438
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5656
# F1 Score: 0.5388
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5798
# F1 Score: 0.5536
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5772
# F1 Score: 0.5507
# Training Round Complete!

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM") # random peturbation (for demonstration)
# mimics some adverserial perturbation instead of the maximally worst case perturbation
serve = FedSAM(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1374
# F1 Score: 0.0737
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1959
# F1 Score: 0.1184
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2610
# F1 Score: 0.2023
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2919
# F1 Score: 0.2418
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3051
# F1 Score: 0.2589
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3329
# F1 Score: 0.2922
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3634
# F1 Score: 0.3283
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3809
# F1 Score: 0.3511
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4011
# F1 Score: 0.3731
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4155
# F1 Score: 0.3838
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4258
# F1 Score: 0.3981
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4358
# F1 Score: 0.4114
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4403
# F1 Score: 0.4130
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4450
# F1 Score: 0.4183
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4602
# F1 Score: 0.4338
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4656
# F1 Score: 0.4399
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4748
# F1 Score: 0.4505
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4798
# F1 Score: 0.4547
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4816
# F1 Score: 0.4592
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4936
# F1 Score: 0.4678
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4998
# F1 Score: 0.4764
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5063
# F1 Score: 0.4778
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5094
# F1 Score: 0.4867
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5178
# F1 Score: 0.4922
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5239
# F1 Score: 0.4966
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5233
# F1 Score: 0.5024
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5258
# F1 Score: 0.5070
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5351
# F1 Score: 0.5100
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5415
# F1 Score: 0.5134
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5394
# F1 Score: 0.5187
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5540
# F1 Score: 0.5339
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5501
# F1 Score: 0.5316
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5645
# F1 Score: 0.5443
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5659
# F1 Score: 0.5494
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5696
# F1 Score: 0.5506
# Training Round Complete!

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedAvg") 
serve = FedAvg(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1620
# F1 Score: 0.0697
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1965
# F1 Score: 0.1217
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2702
# F1 Score: 0.2202
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2982
# F1 Score: 0.2500
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3151
# F1 Score: 0.2737
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3479
# F1 Score: 0.3118
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3719
# F1 Score: 0.3421
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3794
# F1 Score: 0.3500
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4049
# F1 Score: 0.3735
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4157
# F1 Score: 0.3847
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4180
# F1 Score: 0.3867
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4352
# F1 Score: 0.4076
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4329
# F1 Score: 0.4037
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4425
# F1 Score: 0.4126
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4524
# F1 Score: 0.4243
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4579
# F1 Score: 0.4330
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4628
# F1 Score: 0.4390
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4732
# F1 Score: 0.4478
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4858
# F1 Score: 0.4566
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4960
# F1 Score: 0.4669
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4887
# F1 Score: 0.4603
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5073
# F1 Score: 0.4823
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5036
# F1 Score: 0.4804
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5085
# F1 Score: 0.4887
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5094
# F1 Score: 0.4857
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5098
# F1 Score: 0.4872
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5165
# F1 Score: 0.4948
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5345
# F1 Score: 0.5118
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5391
# F1 Score: 0.5149
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5294
# F1 Score: 0.5142
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5467
# F1 Score: 0.5202
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5370
# F1 Score: 0.5171
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5527
# F1 Score: 0.5261
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5539
# F1 Score: 0.5323
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5543
# F1 Score: 0.5338
# Training Round Complete!

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM",mu=0.1) 
serve = FedSAM_Trace(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
serve.run_experiment()
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1111
# F1 Score: 0.0388
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1640
# F1 Score: 0.0791
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2294
# F1 Score: 0.1751
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2557
# F1 Score: 0.2055
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3167
# F1 Score: 0.2749
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3469
# F1 Score: 0.3060
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3714
# F1 Score: 0.3322
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3716
# F1 Score: 0.3383
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3954
# F1 Score: 0.3544
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4075
# F1 Score: 0.3699
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4196
# F1 Score: 0.3767
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4250
# F1 Score: 0.3892
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4310
# F1 Score: 0.3957
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4493
# F1 Score: 0.4149
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4480
# F1 Score: 0.4136
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4582
# F1 Score: 0.4170
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4660
# F1 Score: 0.4260
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4742
# F1 Score: 0.4405
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4771
# F1 Score: 0.4366
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4766
# F1 Score: 0.4449
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4851
# F1 Score: 0.4565
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4992
# F1 Score: 0.4623
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5114
# F1 Score: 0.4732
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5080
# F1 Score: 0.4655
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5182
# F1 Score: 0.4849
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5216
# F1 Score: 0.4869
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5260
# F1 Score: 0.4939
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5248
# F1 Score: 0.4914
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5408
# F1 Score: 0.5074
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5502
# F1 Score: 0.5247
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5457
# F1 Score: 0.5162
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5656
# F1 Score: 0.5431
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5651
# F1 Score: 0.5438
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5703
# F1 Score: 0.5558
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5676
# F1 Score: 0.5426
# Training Round Complete!

# %%
args = Args(training_rounds=35,local_epochs=5,rule_arg=0.3,rho=0.01,lambd=0.1,aggr_scheme="FedSAM_Trace") 
serve = FedSAM_Trace(args)
# Out:
# Data is already downloaded
# Class frequencies:
# Client   0: 0.059, 0.121, 0.057, 0.146, 0.000, 0.278, 0.093, 0.072, 0.019, 0.154, Amount:5000
# Client   1: 0.356, 0.152, 0.120, 0.021, 0.232, 0.000, 0.030, 0.052, 0.012, 0.024, Amount:5000
# Client   2: 0.077, 0.023, 0.082, 0.141, 0.423, 0.001, 0.024, 0.206, 0.025, 0.000, Amount:5000
# Client   3: 0.051, 0.537, 0.161, 0.051, 0.003, 0.013, 0.013, 0.003, 0.109, 0.060, Amount:5000
# Client   4: 0.000, 0.007, 0.025, 0.286, 0.010, 0.002, 0.002, 0.004, 0.084, 0.580, Amount:5000
# Client   5: 0.000, 0.005, 0.342, 0.097, 0.000, 0.062, 0.097, 0.037, 0.322, 0.038, Amount:5000
# Client   6: 0.157, 0.055, 0.067, 0.037, 0.008, 0.292, 0.050, 0.117, 0.102, 0.115, Amount:5000
# Client   7: 0.082, 0.023, 0.043, 0.089, 0.221, 0.032, 0.033, 0.384, 0.076, 0.016, Amount:5000
# Client   8: 0.201, 0.056, 0.074, 0.049, 0.091, 0.018, 0.413, 0.065, 0.033, 0.000, Amount:5000
# Client   9: 0.016, 0.019, 0.030, 0.083, 0.013, 0.301, 0.246, 0.060, 0.219, 0.012, Amount:5000
# Total Amount:50000
# --------
#       Test: 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, 0.100, Amount:10000

# %%
import time
start_time = time.time()
serve.run_experiment()
print("Total Time Taken: ", time.time()-start_time)
print('Average Time per Round: ', (time.time()-start_time)/args.tr_rounds)
print('Experiment Completed')
# Out:
# Data Distributed Among Clients
# Model Parameters Initialized
# Training: Round 1 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1343
# F1 Score: 0.0559
# Training Round Complete!
# Training: Round 2 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.1765
# F1 Score: 0.0945
# Training Round Complete!
# Training: Round 3 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2305
# F1 Score: 0.1719
# Training Round Complete!
# Training: Round 4 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.2822
# F1 Score: 0.2422
# Training Round Complete!
# Training: Round 5 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3198
# F1 Score: 0.2796
# Training Round Complete!
# Training: Round 6 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3397
# F1 Score: 0.3032
# Training Round Complete!
# Training: Round 7 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3714
# F1 Score: 0.3349
# Training Round Complete!
# Training: Round 8 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3823
# F1 Score: 0.3468
# Training Round Complete!
# Training: Round 9 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3951
# F1 Score: 0.3629
# Training Round Complete!
# Training: Round 10 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.3982
# F1 Score: 0.3647
# Training Round Complete!
# Training: Round 11 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4248
# F1 Score: 0.3839
# Training Round Complete!
# Training: Round 12 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4293
# F1 Score: 0.3872
# Training Round Complete!
# Training: Round 13 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4335
# F1 Score: 0.3990
# Training Round Complete!
# Training: Round 14 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4356
# F1 Score: 0.4037
# Training Round Complete!
# Training: Round 15 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4469
# F1 Score: 0.4077
# Training Round Complete!
# Training: Round 16 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4436
# F1 Score: 0.4097
# Training Round Complete!
# Training: Round 17 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4576
# F1 Score: 0.4241
# Training Round Complete!
# Training: Round 18 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4767
# F1 Score: 0.4474
# Training Round Complete!
# Training: Round 19 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4857
# F1 Score: 0.4525
# Training Round Complete!
# Training: Round 20 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.4830
# F1 Score: 0.4531
# Training Round Complete!
# Training: Round 21 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5042
# F1 Score: 0.4636
# Training Round Complete!
# Training: Round 22 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5104
# F1 Score: 0.4774
# Training Round Complete!
# Training: Round 23 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5128
# F1 Score: 0.4792
# Training Round Complete!
# Training: Round 24 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5067
# F1 Score: 0.4731
# Training Round Complete!
# Training: Round 25 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5360
# F1 Score: 0.5078
# Training Round Complete!
# Training: Round 26 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5247
# F1 Score: 0.4886
# Training Round Complete!
# Training: Round 27 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5335
# F1 Score: 0.5045
# Training Round Complete!
# Training: Round 28 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5391
# F1 Score: 0.5040
# Training Round Complete!
# Training: Round 29 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5421
# F1 Score: 0.5145
# Training Round Complete!
# Training: Round 30 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5490
# F1 Score: 0.5284
# Training Round Complete!
# Training: Round 31 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5490
# F1 Score: 0.5245
# Training Round Complete!
# Training: Round 32 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5671
# F1 Score: 0.5455
# Training Round Complete!
# Training: Round 33 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5736
# F1 Score: 0.5513
# Training Round Complete!
# Training: Round 34 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5693
# F1 Score: 0.5455
# Training Round Complete!
# Training: Round 35 / 35
# Local Training Completed
# Global Aggregation Completed
# Accuracy: 0.5623
# F1 Score: 0.5380
# Training Round Complete!
# Total Time Taken:  2576.428238630295
# Average Time per Round:  73.61223538943699
# Experiment Completed
